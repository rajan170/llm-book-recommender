# %%
import kagglehub

path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")
print(path)
# Out:
# ...
# 100%|██████████| 1.47M/1.47M [00:00<00:00, 16.6MB/s]
# Extracting files...
# /Users/rajan/.cache/kagglehub/datasets/dylanjcastillo/7k-books-with-metadata/versions/3
